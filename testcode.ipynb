# %%
# !ls
# Out:
# GitSync.code-workspace	Proc_19_N_mosaic  SR_old_data  pix2pixHD

# %%
cd /Workspace
# Out:
# /Workspace

# %%
from PIL import Image
from torchvision import transforms

# %%
path='Proc_19_N_mosaic/train_A/Proc_19_N_10X_20210114_135641_D_1_300_mosaic_1.tiff'
Img=Image.open(path)
to_tensor=transforms.ToTensor()
tensor_img=to_tensor(Img)

# %%
print(Img.getextrema())
print(Img.size)
print(type(Img))
print(tensor_img.shape)
print(tensor_img.dtype)
print(tensor_img.max())
# Out:
# (818.7529296875, 1712.5992431640625)
# (1537, 1537)
# <class 'PIL.TiffImagePlugin.TiffImageFile'>
# torch.Size([1, 1537, 1537])
# torch.float32
# tensor(1712.5992)
